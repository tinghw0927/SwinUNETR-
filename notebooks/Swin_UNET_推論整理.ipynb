# %% [markdown]
# # 環境設定

# %%
import sys
# !{sys.executable} --version
# !{sys.executable} -m pip install -U numpy==1.26.4
import os
os._exit(0)
# Out:
# Python 3.11.13
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 139.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# ...

# %%
import sys
# !{sys.executable} -m pip install -U ray==2.5.0
import ray
print(ray.__version__)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.4/56.4 MB 44.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 72.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.73.1
#     Uninstalling grpcio-1.73.1:
#       Successfully uninstalled grpcio-1.73.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# grpcio-status 1.71.2 requires grpcio>=1.71.2, but you have grpcio 1.51.3 which is incompatible.
# ...
# 2.5.0

# %%
import sys
# !{sys.executable} -m pip install -U monai==1.2.0
import monai
print(monai.__version__)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 88.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 81.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 112.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 84.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 9.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 44.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 10.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 119.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !{sys.executable} -m pip install -U ml_collections
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 10.4 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/kairaun/Sam.git
# Out:
# Cloning into 'Sam'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# %cd ./Sam
! ls
! head pyproject.toml
# !pip install -e .
import os
os._exit(0)
# Out:
# /content/Sam
# pyproject.toml
# [build-system]
# requires = [
#     "setuptools>=62.3.0,<75.9",
#     "torch>=2.5.1",
#     ]
# build-backend = "setuptools.build_meta"
# Obtaining file:///content/Sam
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for UNKNOWN (pyproject.toml) ... done
#   Created wheel for UNKNOWN: filename=unknown-0.0.0-0.editable-py3-none-any.whl size=2557 sha256=971f49b894dd1b52e4f817176104454d6d14d777d343442c70d8e0e391a2b1bd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-qa2lytq1/wheels/4d/dd/8b/46a6ee24a860a2484f39a9b119ad19ebd742e574a063e7b881
# Successfully built UNKNOWN
# ...

# %%
import sys
# !{sys.executable} -m pip install -U --no-deps monailabel
import monailabel
print(monailabel.__version__)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 80.3 MB/s eta 0:00:00
# ...
# 0.8.5

# %%
# Clone the project
# !git clone https://github.com/kairaun/CardiacSegV2.git
# Out:
# Cloning into 'CardiacSegV2'...
# remote: Enumerating objects: 641, done.
# remote: Counting objects: 100% (105/105), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 641 (delta 93), reused 61 (delta 61), pack-reused 536 (from 1)
# Receiving objects: 100% (641/641), 17.31 MiB | 14.82 MiB/s, done.
# Resolving deltas: 100% (207/207), done.

# %%
# Install the Environment
! sudo chmod 700 /content/CardiacSegV2/setup.sh
! /content/CardiacSegV2/setup.sh
! pip install gdown==4.6.0
# Out:
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,201 kB]
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:5 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [83.6 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# ...

# %%
# Modify the code
! sed -i '8c \\    os.makedirs(\"/content/CardiacSegV2/\"+data_dir, exist_ok=True)' /content/CardiacSegV2/setup_dir.py
! sed -i '20c \\        os.makedirs(\"/content/CardiacSegV2/\"+model_exp_dir, exist_ok=True)' /content/CardiacSegV2/setup_dir.py
! sed -i '29c \\        os.makedirs("/content/CardiacSegV2/"+model_exp_dir, exist_ok=True)' /content/CardiacSegV2/setup_dir.py
! sed -i '3c sys.path.append(\"/content/CardiacSegV2\")' /content/CardiacSegV2/expers/infer.py
! sed -i '3c sys.path.append(\"/content/CardiacSegV2\")' /content/CardiacSegV2/expers/tune.py
! sed -i '36c ray.init(runtime_env={\"working_dir\": \"/content/CardiacSegV2\"})' /content/CardiacSegV2/expers/tune.py

# %%
! python /content/CardiacSegV2/setup_dir.py
# Out:
# mkdir data: dataset/chgh
# mkdir exp: exps/exps/unet3d/chgh/tune_results

# %%
# !ls
# Out:
# CardiacSegV2  Sam  sample_data

# %%
# !pip install "pydantic<2.0"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 18.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 130.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.11.7
#     Uninstalling pydantic-2.11.7:
#       Successfully uninstalled pydantic-2.11.7
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# monailabel 0.8.5 requires bcrypt>=4.1.2, which is not installed.
# monailabel 0.8.5 requires dicomweb-client[gcp]>=0.59.1, which is not installed.
# monailabel 0.8.5 requires expiring_dict>=1.1.0, which is not installed.
# monailabel 0.8.5 requires expiringdict>=1.2.2, which is not installed.
# monailabel 0.8.5 requires girder-client>=3.2.3, which is not installed.
# monailabel 0.8.5 requires ninja>=1.11.1.1, which is not installed.
# ...

# %% [markdown]
# #預備資料 (已經儲存於Google Drive上)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
# create folder in drive
os.makedirs('/content/drive/MyDrive/myo_pred/chgh/image', exist_ok=True)
os.makedirs('/content/drive/MyDrive/myo_pred/chgh/infer', exist_ok=True)

# %%
workspace_dir = '/content/CardiacSegV2'
import sys
sys.path.append(workspace_dir)
import os
import importlib
from pathlib import PurePath

import pandas as pd
from ray import tune
from ray.train.trainer import BaseTrainer

#from datasets.chgh_dataset import get_data_dicts
from data_utils.utils import get_pids_by_data_dicts


def get_tune_model_dir(root_exp_dir, exp_name):
    experiment_path = os.path.join(root_exp_dir, exp_name)

    print(f"Loading results from {experiment_path}...")

    # restored_tuner = tune.Tuner.restore(
    #     experiment_path, trainable=BaseTrainer, resume_errored=True)
    # 727 fix
    restored_tuner = tune.Tuner.restore(experiment_path, trainable='main')
    result_grid = restored_tuner.get_results()

    best_result = result_grid.get_best_result(metric="tt_dice", mode="max")
    print(f"\nBest trial {best_result.metrics['trial_id']}: ")
    print('config:', best_result.metrics['config'])
    print('tt_dice:', best_result.metrics['tt_dice'])
    # print('tt_iou:', best_result.metrics['tt_iou'])
    if 'esc' in best_result.metrics:
        print('esc:', best_result.metrics['esc'])
    print(f'best log dir:', best_result.log_dir)
    model_dir = os.path.join(best_result.log_dir, 'models')
    return model_dir


def get_tune_dir(exp_dir):
    restored_tuner = tune.Tuner.restore(exp_dir)
    result_grid = restored_tuner.get_results()
    best_result = result_grid.get_best_result(metric="tt_dice", mode="max")
    return best_result.log_dir


def get_data_path(data_dir, data_name, pid):
    dataset = importlib.import_module(f'datasets.{data_name}_dataset')
    _get_data_dicts = getattr(dataset, 'get_data_dicts', None)
    data_dicts = _get_data_dicts(data_dir)
    pids = get_pids_by_data_dicts(data_dicts)
    idx = pids.index(pid)
    return data_dicts[idx]


def get_pred_path(root_dir, exp_name, img_pth):
    return os.path.join(
        root_dir,
        'infers',
        exp_name,
        PurePath(img_pth).parts[-1]
    )


def get_eval_csv_path(root_dir):
    return os.path.join(
        root_dir,
        'evals',
        'best_model.csv'
    )


def get_eda_eval_csv_path(root_dir):
    return os.path.join(
        root_dir,
        'eda_evals',
        'best_model.csv'
    )


def get_eval_val(csv_pth, pid):
    df = pd.read_csv(csv_pth)
    idx = df['patientId'] == pid
    if 'inf_diceLV' in df[idx]:
        return {
            'dice': df[idx].filter(regex=("inf_dice*")).T.mean().tolist()[0],
            'iou': df[idx].filter(regex=("inf_iou*")).T.mean().tolist()[0]
        }
    else:
        return {
            'dice': df[idx]['inf_diceC'].tolist()[0],
            'iou': df[idx]['inf_iouC'].tolist()[0]
        }


def get_slice(img, slice_idx, mode, is_trans):
    '''
    mode: a, c, s
    '''
    if mode == 'a':
        img = img[:, :, slice_idx]
    elif mode == 's':
        img = img[:, slice_idx, :]
    else:
        img = img[slice_idx, :, :]

    if is_trans:
        return img.T
    else:
        return img


def get_img_lbl_preds(data, exp_names, slice_idxs, mode='a', is_trans=False):
    '''
    mode: a, c, s
    '''
    preds = []
    imgs = []
    lbls = []
    for slice_idx in slice_idxs:
        pred_ls = []
        for exp_name in exp_names:
            pred_ls.append(
                get_slice(data[exp_name], slice_idx, mode, is_trans))
        preds.append(pred_ls)
        imgs.append(get_slice(data['image'], slice_idx, mode, is_trans))
        lbls.append(get_slice(data['label'], slice_idx, mode, is_trans))
    return imgs, lbls, preds

# %% [markdown]
# # 確定Google Drive內容

# %%
import os
pred_img = []
for root, dirs, files in os.walk("/content/drive/MyDrive/myo_pred/chgh/image", topdown=False):
  for name in files:
    pred_img.append(os.path.join(root, name))
    print(os.path.join(root, name))
# Out:
# /content/drive/MyDrive/myo_pred/chgh/image/patient0098.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0054.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0082.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0071.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0094.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0069.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0096.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0089.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0062.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0084.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0090.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0060.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0100.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0055.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0052.nii.gz
# ...

# %% [markdown]
# # 推論設定

# %%
# 推論設定

import os
import sys
import shutil

# 掛載 Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 基本設定
workspace_dir = '/content/CardiacSegV2'
sys.path.append(workspace_dir)

model_name = 'swinunetr'  # ⭐ 改成 swinunetr
data_name = 'chgh'

# 設定路徑
data_dir = '/content/CardiacSegV2/dataset/chgh'
infer_dir = '/content/drive/MyDrive/myo_pred/chgh/infer'
os.makedirs(infer_dir, exist_ok=True)

# 從 Google Drive 複製模型
print("-" * 70)
print(" 從 Google Drive 載入 SwinUNETR 模型 ".center(70))

# Google Drive 中的 SwinUNETR 模型位置
drive_model_path = '/content/drive/MyDrive/CardiacSeg_Checkpoints_SwinUNETR/best_model.pth'

# Colab 中的模型目標位置
model_dir = '/content/CardiacSegV2/models'
best_checkpoint = '/content/CardiacSegV2/models/best_model.pth'

# 建立目錄並複製模型
os.makedirs(model_dir, exist_ok=True)

if os.path.exists(drive_model_path):
    print(f"✓ 找到 Drive 中的 SwinUNETR 模型: {drive_model_path}")

    # 複製模型
    shutil.copy(drive_model_path, best_checkpoint)
    print(f"✓ 已複製到: {best_checkpoint}")

    # 顯示檔案大小
    size_mb = os.path.getsize(best_checkpoint) / (1024**2)
    print(f"  檔案大小: {size_mb:.2f} MB")

    print(f"\n✓ 推論輸出: {infer_dir}")
    print(f"✓ 資料目錄: {data_dir}")
    print("=" * 70)
    print("\n✓ 設定完成，可以開始推論！")

else:
    print(f"✗ 找不到模型: {drive_model_path}")
    print("\n可能的原因：")
    print("  1. 路徑不正確")
    print("  2. 尚未完成 SwinUNETR 訓練")
    print("\n請檢查你的 Google Drive 中是否有模型檔案")
    print("=" * 70)

    # 搜尋 Drive 中可能的模型位置
    print("\n搜尋 Drive 中的模型檔案...")
    # !find /content/drive/MyDrive -name "best_model.pth" -type f 2>/dev/null

    raise FileNotFoundError("請先完成 SwinUNETR 訓練")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ----------------------------------------------------------------------
#                     從 Google Drive 載入 SwinUNETR 模型
# ✓ 找到 Drive 中的 SwinUNETR 模型: /content/drive/MyDrive/CardiacSeg_Checkpoints_SwinUNETR/best_model.pth
# ✓ 已複製到: /content/CardiacSegV2/models/best_model.pth
#   檔案大小: 719.04 MB
#
# ✓ 推論輸出: /content/drive/MyDrive/myo_pred/chgh/infer
# ✓ 資料目錄: /content/CardiacSegV2/dataset/chgh
# ...
#
# ✓ 設定完成，可以開始推論！

# %% [markdown]
# # 執行推論

# %%
# 執行推論

import os
import shutil

# Define paths
infer_dir = '/content/drive/MyDrive/myo_pred/chgh/infer'
data_dir = '/content/CardiacSegV2/dataset/chgh'
model_dir = '/content/CardiacSegV2/models'
best_checkpoint = '/content/CardiacSegV2/models/best_model.pth'
model_name = 'swinunetr'   # ⭐ 改為 swinunetr
data_name = 'chgh'

# Define pred_img
pred_img = []
for root, dirs, files in os.walk("/content/drive/MyDrive/myo_pred/chgh/image", topdown=False):
  for name in files:
    pred_img.append(os.path.join(root, name))

print("-" * 70)
print(f" 開始 SwinUNETR 推論 ({len(pred_img)} 張圖片) ".center(70))

# 執行推論
for i, img_pth in enumerate(pred_img, 1):
    img_name = os.path.basename(img_pth)
    print(f"\n[{i}/{len(pred_img)}] 推論: {img_name}")
    print("-" * 70)

    # !python /content/CardiacSegV2/expers/infer.py \
      --model_name={model_name} \
      --data_name={data_name} \
      --data_dir={data_dir} \
      --model_dir={model_dir} \
      --infer_dir={infer_dir} \
      --checkpoint={best_checkpoint} \
      --img_pth="{img_pth}" \
      --out_channels=4 \
      --feature_size=48 \
      --drop_rate=0.0 \
      --norm_name='instance' \
      --a_min=-80 \
      --a_max=450 \
      --space_x=0.7 \
      --space_y=0.7 \
      --space_z=1.0 \
      --roi_x=128 \
      --roi_y=128 \
      --roi_z=128 \
      --infer_post_process

print(" ✓ SwinUNETR 推論完成".center(70))

# 儲存
renamed_count = 0
skipped_count = 0

for filename in sorted(os.listdir(infer_dir)):
    if not filename.endswith('.nii.gz'):
        continue

    if '_predict.nii.gz' in filename:
        skipped_count += 1
        continue

    old_path = os.path.join(infer_dir, filename)
    base_name = filename.replace('.nii.gz', '')
    new_name = f"{base_name}_predict.nii.gz"
    new_path = os.path.join(infer_dir, new_name)

    if os.path.exists(new_path):
        os.remove(new_path)

    shutil.move(old_path, new_path)
    print(f"✓ {filename:30s} → {new_name}")
    renamed_count += 1

print("-" * 70)
if renamed_count > 0:
    print(f"✓ 重新命名 {renamed_count} 個檔案")
if skipped_count > 0:
    print(f"  跳過 {skipped_count} 個已有 _predict 的檔案")

# 顯示結果
print("\n" + "=" * 70)
print(" 推論結果 ".center(70))
print("=" * 70)
print(f"儲存位置: {infer_dir}\n")
# !ls -lh {infer_dir}
# Out:
# ...
#                        開始 SwinUNETR 推論 (50 張圖片)
# ...
#
# [1/50] 推論: patient0098.nii.gz
# ----------------------------------------------------------------------
# 2025-11-27 18:00:32.282972: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764266432.304611    5877 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764266432.311017    5877 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
# ...

# %%
# 針對不同類別後處理
import os
import numpy as np
import nibabel as nib
import scipy.ndimage as ndimage
from tqdm import tqdm

print("=" * 70)
print("後處理（針對不同類別優化）")
print("=" * 70)

infer_dir = '/content/drive/MyDrive/myo_pred/chgh/infer'

# 針對不同類別的參數
CLASS_PARAMS = {
    1: {'min_size': 500, 'keep_largest': True, 'fill_holes': True},   # LV（左心室）
    2: {'min_size': 300, 'keep_largest': True, 'fill_holes': True},   # MYO（心肌）
    3: {'min_size': 20, 'keep_largest': False, 'fill_holes': False},  # CA（冠狀動脈）⭐
}

def post_process_single(pred_mask):
    """
    針對不同類別使用不同後處理策略
    """
    result = np.zeros_like(pred_mask)

    for class_id, params in CLASS_PARAMS.items():
        binary = (pred_mask == class_id).astype(np.uint8)

        if binary.sum() == 0:
            continue

        # 1. 標記連通區域
        labeled, num_features = ndimage.label(binary)

        if num_features == 0:
            continue

        # 2. 移除小區域
        if params['min_size'] > 0:
            sizes = ndimage.sum(binary, labeled, range(1, num_features + 1))
            for i, size in enumerate(sizes, 1):
                if size < params['min_size']:
                    binary[labeled == i] = 0

        # 3. 是否只保留最大連通區域
        if params['keep_largest']:
            labeled, num_features = ndimage.label(binary)
            if num_features > 1:
                sizes = ndimage.sum(binary, labeled, range(1, num_features + 1))
                largest_label = np.argmax(sizes) + 1
                binary = (labeled == largest_label).astype(np.uint8)

        # 4. 填充孔洞
        if params['fill_holes']:
            binary = ndimage.binary_fill_holes(binary).astype(np.uint8)

        # 寫入結果
        result[binary > 0] = class_id

    return result

# 處理檔案
predict_files = sorted([f for f in os.listdir(infer_dir) if f.endswith('_predict.nii.gz')])

print(f"找到 {len(predict_files)} 個預測檔案")
print("\n後處理參數:")
for class_id, params in CLASS_PARAMS.items():
    class_names = {1: 'LV', 2: 'MYO', 3: 'CA'}
    print(f"  {class_names[class_id]}:")
    print(f"    - 最小大小: {params['min_size']}")
    print(f"    - 只保留最大: {params['keep_largest']}")
    print(f"    - 填充孔洞: {params['fill_holes']}")
print("-" * 70)

for filename in tqdm(predict_files, desc="後處理進度"):
    file_path = os.path.join(infer_dir, filename)

    nii = nib.load(file_path)
    pred_data = nii.get_fdata().astype(np.int32)
    affine = nii.affine

    # 執行後處理
    processed_data = post_process_single(pred_data)

    # 儲存
    processed_nii = nib.Nifti1Image(processed_data.astype(np.int16), affine)
    nib.save(processed_nii, file_path)

print("-" * 70)
print(f"完成 {len(predict_files)} 個檔案")
print(f"儲存位置: {infer_dir}")
# Out:
# ...
# 🔧 執行智能後處理（針對不同類別優化）
# ...
# 找到 50 個預測檔案
#
# 後處理參數:
#   LV:
#     - 最小大小: 500
#     - 只保留最大: True
#     - 填充孔洞: True
#   MYO:
#     - 最小大小: 300
#     - 只保留最大: True
#     - 填充孔洞: True
#   CA:
#     - 最小大小: 20
#     - 只保留最大: False
#     - 填充孔洞: False
# ----------------------------------------------------------------------
# 後處理進度: 100%|██████████| 50/50 [44:26<00:00, 53.32s/it]
# ----------------------------------------------------------------------
# ✅ 完成 50 個檔案
# ✅ 儲存位置: /content/drive/MyDrive/myo_pred/chgh/infer

# %% [markdown]
# # 壓縮結果上傳檔案

# %%
# 壓縮推論結果

import zipfile
import os

infer_dir = '/content/drive/MyDrive/myo_pred/chgh/infer'
zip_output = '/content/drive/MyDrive/myo_pred/chgh/predict.zip'


# 取得所有 _predict.nii.gz 檔案
predict_files = sorted([f for f in os.listdir(infer_dir) if f.endswith('_predict.nii.gz')])

if not predict_files:
    print("✗ 找不到任何 _predict.nii.gz 檔案！")
else:
    print(f"找到 {len(predict_files)} 個檔案\n")

    # 建立 zip
    with zipfile.ZipFile(zip_output, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for filename in predict_files:
            file_path = os.path.join(infer_dir, filename)
            zipf.write(file_path, arcname=filename)
            print(f"✓ {filename}")

    # 檢查結果
    zip_size_mb = os.path.getsize(zip_output) / (1024**2)

    print("\n" + "=" * 70)
    print(" ✓ 壓縮完成！".center(70))
    print("=" * 70)
    print(f"檔案: {zip_output}")
    print(f"大小: {zip_size_mb:.2f} MB")
    print(f"包含: {len(predict_files)} 個檔案")

# 下載到本機
from google.colab import files
files.download(zip_output)
# Out:
# ...
#                                 壓縮推論結果
# ...
# 找到 50 個檔案
#
# ✓ patient0051_predict.nii.gz
# ✓ patient0052_predict.nii.gz
# ✓ patient0053_predict.nii.gz
# ✓ patient0054_predict.nii.gz
# ✓ patient0055_predict.nii.gz
# ✓ patient0056_predict.nii.gz
# ✓ patient0057_predict.nii.gz
# ✓ patient0058_predict.nii.gz
# ✓ patient0059_predict.nii.gz
# ✓ patient0060_predict.nii.gz
# ✓ patient0061_predict.nii.gz
# ✓ patient0062_predict.nii.gz
# ✓ patient0063_predict.nii.gz
# ✓ patient0064_predict.nii.gz
# ✓ patient0065_predict.nii.gz
# ✓ patient0066_predict.nii.gz
# ✓ patient0067_predict.nii.gz
# ✓ patient0068_predict.nii.gz
# ✓ patient0069_predict.nii.gz
# ✓ patient0070_predict.nii.gz
# ✓ patient0071_predict.nii.gz
# ✓ patient0072_predict.nii.gz
# ✓ patient0073_predict.nii.gz
# ✓ patient0074_predict.nii.gz
# ✓ patient0075_predict.nii.gz
# ✓ patient0076_predict.nii.gz
# ✓ patient0077_predict.nii.gz
# ✓ patient0078_predict.nii.gz
# ✓ patient0079_predict.nii.gz
# ✓ patient0080_predict.nii.gz
# ...
